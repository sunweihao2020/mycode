# %%
import numpy as np
import xarray as xr

f0  =  xr.open_dataset("/home/sun/mydown/model_input/b1850/ocean_hgrid_180829.nc")
f0
# Out:
# <xarray.Dataset>
# Dimensions:   (nyp: 917, nxp: 1081, ny: 916, nx: 1080)
# Dimensions without coordinates: nyp, nxp, ny, nx
# Data variables:
#     tile      |S255 ...
#     y         (nyp, nxp) float64 ...
#     x         (nyp, nxp) float64 ...
#     dy        (ny, nxp) float64 ...
#     dx        (nyp, nx) float64 ...
#     area      (ny, nx) float64 ...
#     angle_dx  (nyp, nxp) float64 ...
# Attributes:
#     file_name:    tx0.66v1_hgrid_2018-03-27.nc
#     Description:
#     Author:       Gustavo Marques (gmarques@ucar.edu)
#     Created:      2018-03-27T09:38:19.474327
#     type:         MOM6 supergrid file

# %%
f1  =  xr.open_dataset("/home/sun/mydown/model_input/b1850/vgrid_65L_20200626.nc")
f1
# Out:
# <xarray.Dataset>
# Dimensions:  (z: 65)
# Dimensions without coordinates: z
# Data variables:
#     dz       (z) float64 ...
# Attributes:
#     title:          Vertical resolution using 65 layers
#     maximum_depth:  6000.0 m
#     minimum_depth:  10 m
#     url:            created using https://gist.github.com/gustavo-marques/3e1...
#     author:         Gustavo Marques (gmarques@ucar.edu)
#     Created:        2020-06-26T12:04:45.719416

# %%
f2  =  xr.open_dataset("/home/sun/mydown/model_input/b1850/ocean_topog_200701.nc")
f2
# Out:
# <xarray.Dataset>
# Dimensions:  (ny: 458, nx: 540)
# Coordinates:
#   * ny       (ny) float32 -79.2 -79.08 -78.95 -78.82 ... 65.7 65.79 65.87 65.96
#   * nx       (nx) float32 -286.7 -286.0 -285.3 -284.7 ... 70.67 71.33 72.0 72.67
# Data variables:
#     depth    (ny, nx) float32 ...
#     mask     (ny, nx) float32 ...
# Attributes:
#     title:         Edited topography for grid tx0.66v1
#     Author:        Gustavo Marques (gmarques@ucar.edu)
#     Created:       2020-07-01T09:54:39.431688
#     MaxDepth:      6000.0 m
#     MinDepth:      10.0 m
#     MaskingDepth:  0.0 m
#     FilesUsed:     ocean_topog_180829.nc
#     Description:   Edited topography for grid tx0.66v1
#     url:           Generated using the following notebook: https://gist.githu...

# %%
import numpy as np
import matplotlib.pyplot as plt
fig1, ax2 = plt.subplots(constrained_layout=True)
CS = ax2.contourf(f2.mask)

# %%
f3  =  xr.open_dataset("/home/sun/mydown/model_input/b1850/state_restore_tx0.66v1_20200616.nc")
f3
# Out:
# <xarray.Dataset>
# Dimensions:  (TIME: 12, LAT: 458, LON: 540)
# Coordinates:
#   * TIME     (TIME) object 0001-01-16 00:00:00 ... 0001-12-16 00:00:00
#   * LAT      (LAT) float64 -79.2 -79.08 -78.95 -78.82 ... 49.98 49.99 49.99
#   * LON      (LON) float64 -286.7 -286.0 -285.3 -284.7 ... 71.33 72.0 72.67
# Data variables:
#     salt     (TIME, LAT, LON) float32 ...
#     theta0   (TIME, LAT, LON) float64 ...
# Attributes:
#     title:          surface salinity and potential temperature from WOA fille...
#     src_file:       ./woa18_sfc_state_filled.nc
#     src_grid_name:  WOA_04
#     dst_grid_name:  tx0.66v1
#     author:         Gustavo Marques (gmaques@ucar.edu)
#     date:           2020-06-16T17:23:13.695549
#     created_using:  regrid_sfc_state.py -path_out ./ -author Gustavo Marques ...
#     url:            regrid_sfc_state.py can be found at https://github.com/NC...
#     git_hash:       b'ff45556'

# %%
fig1, ax2 = plt.subplots(constrained_layout=True)
CS = ax2.contourf(f3.salt[0])

# %%
f5  =  xr.open_dataset("/home/sun/data/woa18_04_initial_conditions.nc",decode_times=False)
f5
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 720, lon: 1440, depth: 102)
# Coordinates:
#   * lat      (lat) float64 -89.88 -89.62 -89.38 -89.12 ... 89.38 89.62 89.88
#   * lon      (lon) float64 -179.9 -179.6 -179.4 -179.1 ... 179.4 179.6 179.9
#     time     float32 ...
#   * depth    (depth) float64 0.0 5.0 10.0 15.0 ... 5.3e+03 5.4e+03 5.5e+03
# Data variables:
#     s_an     (depth, lat, lon) float32 ...
#     theta0   (depth, lat, lon) float32 ...
# Attributes:
#     title:           T and S from WOA filled over continents
#     WOA_resolution:  04, 01 (1 deg), 04 (0.25 deg)
#     author:          Gustavo Marques (gmarques@ucar.edu)
#     date:            2020-06-16T16:35:25.114337
#     created_using:   create_filled_ic.py -path_out ./ -author Gustavo Marques...
#     url:             create_filled_ic.py can be found at https://github.com/N...
#     git_hash:        b'4b2f95e'

# %%
fig1, ax2 = plt.subplots(constrained_layout=True)
CS = ax2.contourf(f5.theta0[20])

# %%
f6  =  xr.open_dataset("/home/sun/mydown/model_input/b1850/energy_new_t0.66v1_conserve_190315.nc")
f6
# Out:
# <xarray.Dataset>
# Dimensions:           (lat: 458, lon: 540)
# Dimensions without coordinates: lat, lon
# Data variables:
#     wave_dissipation  (lat, lon) float64 ...
# Attributes:
#     description:  tidal energy dissipation interpolated from Jayne
#     author:       altuntas@ucar.edu

# %%
fig1, ax2 = plt.subplots(constrained_layout=True)
CS = ax2.contourf(f6.wave_dissipation)

# %%
f7 = xr.open_dataset("/home/sun/mydown/model_input/b1850/tx0.66v1_SCRIP_190314.nc")
f7
# Out:
# <xarray.Dataset>
# Dimensions:          (grid_rank: 2, grid_size: 247320, grid_corners: 4)
# Dimensions without coordinates: grid_rank, grid_size, grid_corners
# Data variables:
#     grid_dims        (grid_rank) int32 ...
#     grid_center_lat  (grid_size) float64 ...
#     grid_center_lon  (grid_size) float64 ...
#     grid_imask       (grid_size) int32 ...
#     grid_corner_lat  (grid_size, grid_corners) float64 ...
#     grid_corner_lon  (grid_size, grid_corners) float64 ...
#     grid_area        (grid_size) float64 ...
# Attributes:
#     date_created:  Thu Mar 14 14:15:56 MDT 2019
#     Createdby:     ESMF_regridding.ncl
#     Conventions:   SCRIP
#     title:         tx0.66v1 Grid
