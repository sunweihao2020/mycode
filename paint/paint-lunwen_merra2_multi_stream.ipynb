# %% [markdown]
# # 2021/11/23
# # 本代码绘制925 700 500的环流图
# # 使用数据为合成的merra2数据

# %%
import os
import sys
import xarray as xr
import numpy as np
module_path = ["/home/sun/mycode/module/","/data5/2019swh/mycode/module/"]
sys.path.append(module_path[0])
from module_sun import *
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
from metpy.units import units
from matplotlib.path import Path
import matplotlib.patches as patches

# %%
path  =  "/home/sun/qomo-data/"
level =  [925,850,700,500]
lon_slice  =  slice(30,120)
lat_slice  =  slice(-15,40)

lonmin,lonmax,latmin,latmax  =  40,120,-10,30
extent     =  [lonmin,lonmax,latmin,latmax]

f  =  xr.open_dataset(path+"composite3.nc").sel(level=level[0],lon=lon_slice,lat=lat_slice)

# %% [markdown]
# # 绘制单个时次进行挑选

# %%
dates  =  [-12,-9,-6,-3,0,3] #总共6张图
date   =  [18,21,24,27,30,33]
props = dict(boxstyle='square', edgecolor='white', facecolor='white', alpha=1)

proj    =  ccrs.PlateCarree()
fig1    =  plt.figure(figsize=(12,10))
spec1   =  fig1.add_gridspec(nrows=3,ncols=2)

j = 0
    
for col in range(2):
    for row in range(3):
            ax = fig1.add_subplot(spec1[row,col],projection=proj)
            ax.coastlines(resolution='110m',lw=1)
            # 设置经纬度刻度.
            set_map_ticks(ax, dx=10, dy=10, nx=1, ny=1, labelsize='small')
            ax.set_extent(extent, crs=proj)
            
            ax.plot([40,120],[0,0],'k--')
            ax.streamplot(f.lon.data, f.lat.data, 
                          f.uwind.data[date[j],:], f.vwind.data[date[j],:], 
                          color='k',linewidth=1.1,arrowstyle='->',
                         density=1.5)
            ax.text(0.85,0.825,"D"+str(dates[j]),transform=ax.transAxes,bbox=props,fontsize=15)
        
            j += 1

    

plt.tight_layout()
plt.savefig("/home/sun/paint/composite/stream/stream_six_times_"+str(level[0])+".pdf", bbox_inches='tight')
plt.show()

# %%
f  =  xr.open_dataset(path+"composite3.nc").sel(level=level[1],lon=lon_slice,lat=lat_slice)   

proj    =  ccrs.PlateCarree()
fig1    =  plt.figure(figsize=(12,10))
spec1   =  fig1.add_gridspec(nrows=3,ncols=2)

j = 0
    
for col in range(2):
    for row in range(3):
            ax = fig1.add_subplot(spec1[row,col],projection=proj)
            ax.coastlines(resolution='110m',lw=1)
            # 设置经纬度刻度.
            set_map_ticks(ax, dx=10, dy=10, nx=1, ny=1, labelsize='small')
            ax.set_extent(extent, crs=proj)
            
            ax.plot([40,120],[0,0],'k--')
            ax.streamplot(f.lon.data, f.lat.data, 
                          f.uwind.data[date[j],:], f.vwind.data[date[j],:], 
                          color='k',linewidth=1.1,arrowstyle='->',
                         density=1.5)
            ax.text(0.85,0.825,"D"+str(dates[j]),transform=ax.transAxes,bbox=props,fontsize=15)
        
            j += 1

plt.tight_layout()
plt.savefig("/home/sun/paint/composite/stream/stream_six_times_"+str(level[1])+".pdf", bbox_inches='tight')
plt.show()

# %%
f  =  xr.open_dataset(path+"composite3.nc").sel(level=level[2],lon=lon_slice,lat=lat_slice)   

proj    =  ccrs.PlateCarree()
fig1    =  plt.figure(figsize=(12,10))
spec1   =  fig1.add_gridspec(nrows=3,ncols=2)

j = 0
    
for col in range(2):
    for row in range(3):
            ax = fig1.add_subplot(spec1[row,col],projection=proj)
            ax.coastlines(resolution='110m',lw=1)
            # 设置经纬度刻度.
            set_map_ticks(ax, dx=10, dy=10, nx=1, ny=1, labelsize='small')
            ax.set_extent(extent, crs=proj)
            
            ax.plot([40,120],[0,0],'k--')
            ax.streamplot(f.lon.data, f.lat.data, 
                          f.uwind.data[date[j],:], f.vwind.data[date[j],:], 
                          color='k',linewidth=1.1,arrowstyle='->',
                         density=1.5)
            ax.text(0.85,0.825,"D"+str(dates[j]),transform=ax.transAxes,bbox=props,fontsize=15)
        
            j += 1
            
plt.tight_layout()
plt.savefig("/home/sun/paint/composite/stream/stream_six_times_"+str(level[2])+".pdf", bbox_inches='tight')
plt.show()

# %%
f  =  xr.open_dataset(path+"composite3.nc").sel(level=level[3],lon=lon_slice,lat=lat_slice)   

proj    =  ccrs.PlateCarree()
fig1    =  plt.figure(figsize=(12,10))
spec1   =  fig1.add_gridspec(nrows=3,ncols=2)

j = 0
    
for col in range(2):
    for row in range(3):
            ax = fig1.add_subplot(spec1[row,col],projection=proj)
            ax.coastlines(resolution='110m',lw=1)
            # 设置经纬度刻度.
            set_map_ticks(ax, dx=10, dy=10, nx=1, ny=1, labelsize='small')
            ax.set_extent(extent, crs=proj)
            
            ax.plot([40,120],[0,0],'k--')
            ax.streamplot(f.lon.data, f.lat.data, 
                          f.uwind.data[date[j],:], f.vwind.data[date[j],:], 
                          color='k',linewidth=1.1,arrowstyle='->',
                         density=1.5)
            ax.text(0.85,0.825,"D"+str(dates[j]),transform=ax.transAxes,bbox=props,fontsize=15)
        
            j += 1
            
plt.tight_layout()
plt.savefig("/home/sun/paint/composite/stream/stream_six_times_"+str(level[3])+".pdf", bbox_inches='tight')
plt.show()

# %%
f  =  xr.open_dataset(path+"composite3.nc").sel(level=level[2],lon=lon_slice,lat=lat_slice)   

proj    =  ccrs.PlateCarree()
fig1    =  plt.figure(figsize=(12,10))
spec1   =  fig1.add_gridspec(nrows=3,ncols=2)

j = 0

props = dict(boxstyle='square', edgecolor='white', facecolor='white', alpha=1)

dates  =  [3,6,9,12,15,18] #总共6张图
date   =  [33,37,40,43,46,49]
    
for col in range(2):
    for row in range(3):
            ax = fig1.add_subplot(spec1[row,col],projection=proj)
            ax.coastlines(resolution='110m',lw=1)
            # 设置经纬度刻度.
            set_map_ticks(ax, dx=10, dy=10, nx=1, ny=1, labelsize='small')
            ax.set_extent(extent, crs=proj)
            
            ax.plot([40,120],[0,0],'k--')
            ax.streamplot(f.lon.data, f.lat.data, 
                          f.uwind.data[date[j],:], f.vwind.data[date[j],:], 
                          color='k',linewidth=1.1,arrowstyle='->',
                         density=1.5)
            ax.text(0.85,0.825,"D"+str(dates[j]),transform=ax.transAxes,bbox=props,fontsize=15)
        
            j += 1
            
#plt.tight_layout()
#plt.savefig("/home/sun/paint/composite/stream/stream_six_times_"+str(level[2])+".pdf", bbox_inches='tight')
#plt.show()
