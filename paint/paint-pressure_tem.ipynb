# %% [markdown]
# # 2021/11/24
# # 本代码我想看一下脊线断裂区的经向温度

# %%
import os
import sys
import xarray as xr
import numpy as np
module_path = ["/home/sun/mycode/module/","/data5/2019swh/mycode/module/"]
sys.path.append(module_path[0])
from module_sun import *
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
from metpy.units import units
from matplotlib.path import Path
import matplotlib.patches as patches

path  =  "/home/sun/qomo-data/"
level =  [925,850,700,500]
lat_slice  =  slice(-15,30)


f  =  xr.open_dataset(path+"composite3.nc").sel(level=level[2],lon=105,lat=lat_slice)

# %%
fig,ax = plt.subplots()

ax.plot(f.lat.data,f.T.data[20,:])

# %%
fig,ax = plt.subplots()

ax.plot(f.lat.data,f.T.data[40,:])

# %%
fig,ax = plt.subplots()

ax.plot(f.lat.data,f.T.data[50,:])

# %%
f  =  xr.open_dataset(path+"composite3.nc").sel(level=850,lon=95,lat=lat_slice)

# %%
fig,ax = plt.subplots()

ax.plot(f.lat.data,f.T.data[20,:])

# %%
fig,ax = plt.subplots()

ax.plot(f.lat.data,f.T.data[30,:])

# %%
fig,ax = plt.subplots()

ax.plot(f.lat.data,f.T.data[35,:])

# %%
fig,ax = plt.subplots()

ax.plot(f.lat.data,f.T.data[45,:])

# %%
fig,ax = plt.subplots()

ax.plot(f.lat.data,f.T.data[50,:])
