# %%
import numpy as np
import matplotlib.pyplot as plt

# evenly sampled time at 200ms intervals
index1 = [
    0.08480447983351740,
    0.0384269454036997,
    -0.03415481831954280,
    0.275100154363183,
    0.25127745495390100,
    0.21024993470047200
    ]

index2 = [
    0.17484859424591600,
    0.21911251331356900,
    0.17828395380871300,
    0.2989349551754740,
    0.13574852011262700,
    0.08747879870561190,
]


# red dashes, blue squares and green triangles
plt.plot(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun'], index1, 'r-o', label='South BOB')
plt.plot(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun'], index2, 'k-*', label='Tropical IO')

plt.plot(['Jan', 'Jun'], [0.20, 0.20], 'k--', linewidth=0.8)
plt.plot(['Jan', 'Jun'], [0.24, 0.24], 'g--', linewidth=0.8)
plt.plot(['Jan', 'Jun'], [0.32, 0.32], 'r--', linewidth=0.8)
plt.ylim((-0.1, 0.5))
plt.title('SST correlation', loc='left')

plt.legend()
plt.savefig('/home/sun/paint/index_correlation_with_onsetdate/SST_index_Jan_Jun.png', dpi=500)
plt.show()

# %%
index3 = [
    0.103269746835732,
    -0.1082903358592200,
    0.3005239138969980,
    0.5122172832258310,
    0.299234960900591,
    0.11774237427170800,
]

# red dashes, blue squares and green triangles
plt.plot(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun'], index3, 'k-o', label='LSTC')

plt.plot(['Jan', 'Jun'], [0.20, 0.20], 'k--', linewidth=0.8)
plt.plot(['Jan', 'Jun'], [0.24, 0.24], 'g--', linewidth=0.8)
plt.plot(['Jan', 'Jun'], [0.32, 0.32], 'r--', linewidth=0.8)
plt.ylim((-0.15, 0.6))
plt.title('LSTC correlation', loc='left')

plt.legend()
plt.savefig('/home/sun/paint/index_correlation_with_onsetdate/LSTC_index_Jan_Jun.png', dpi=500)
plt.show()

# %%
index4 = [
    0.14528495413352900,
    0.39602667424833300,
    0.5352559694709230,
    0.7537273082446790,
    0.23293921498642600,
    0.1273747253487160,
]

# red dashes, blue squares and green triangles
plt.plot(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun'], index4, 'k-o', label='South BOB U')

plt.plot(['Jan', 'Jun'], [0.20, 0.20], 'k--', linewidth=0.8)
plt.plot(['Jan', 'Jun'], [0.24, 0.24], 'g--', linewidth=0.8)
plt.plot(['Jan', 'Jun'], [0.32, 0.32], 'r--', linewidth=0.8)
plt.ylim((-0., 0.8))
plt.title('South BOB U correlation', loc='left')

plt.legend()
plt.savefig('/home/sun/paint/index_correlation_with_onsetdate/U_index_Jan_Jun.png', dpi=500)
plt.show()

# %%
index5 = [
    0.45335143812051900,
    0.5264158007396680,
    0.5027712600523470,
    0.6587691523075080,
    0.4379982097233320,
    0.25673756163519700,
]

# red dashes, blue squares and green triangles
plt.plot(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun'], index5, 'k-o', label='Maritime OLR')

plt.plot(['Jan', 'Jun'], [0.20, 0.20], 'k--', linewidth=0.8)
plt.plot(['Jan', 'Jun'], [0.24, 0.24], 'g--', linewidth=0.8)
plt.plot(['Jan', 'Jun'], [0.32, 0.32], 'r--', linewidth=0.8)
plt.ylim((-0., 0.8))
plt.title('Maritime OLR', loc='left')

plt.legend()
plt.savefig('/home/sun/paint/index_correlation_with_onsetdate/OLR_index_Jan_Jun.png', dpi=500)
plt.show()
