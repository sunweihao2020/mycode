# %%
import xarray as xr
import numpy as np

f0  =  xr.open_dataset("/home/sun/mydown/model_input/b1850/ocean_hgrid.nc")
f1  =  xr.open_dataset("/home/sun/mydown/model_input/b1850/ocean_vgrid.nc")
f2  =  xr.open_dataset("/home/sun/mydown/model_input/b1850/ocean_topog.nc")
f3  =  xr.open_dataset("/home/sun/mydown/model_input/b1850/WOA05_pottemp_salt.nc")

# %%
f3
# Out:
# <xarray.Dataset>
# Dimensions:  (TIME: 12, DEPTH: 33, LAT: 180, LON: 360)
# Coordinates:
#   * TIME     (TIME) object 0001-01-16 00:00:00 ... 0001-12-16 00:00:00
#   * DEPTH    (DEPTH) float64 0.0 10.0 20.0 30.0 ... 4e+03 4.5e+03 5e+03 5.5e+03
#   * LAT      (LAT) float64 -89.5 -88.5 -87.5 -86.5 -85.5 ... 86.5 87.5 88.5 89.5
#   * LON      (LON) float64 0.5 1.5 2.5 3.5 4.5 ... 355.5 356.5 357.5 358.5 359.5
# Data variables:
#     PTEMP    (TIME, DEPTH, LAT, LON) float32 ...
#     SALT     (TIME, DEPTH, LAT, LON) float32 nan nan nan nan ... nan nan nan nan

# %%
import numpy as np
import matplotlib.pyplot as plt

fig1, ax2 = plt.subplots(constrained_layout=True)
CS = ax2.contourf(f3.SALT[0,0,:,:], 10, cmap=plt.cm.bone, origin='lower')

cbar = fig1.colorbar(CS)

# %%
import numpy as np
import matplotlib.pyplot as plt

fig1, ax2 = plt.subplots(constrained_layout=True)
CS = ax2.contourf(f2.depth, 10, cmap=plt.cm.bone, origin='lower')




cbar = fig1.colorbar(CS)
cbar.ax.set_ylabel('verbosity coefficient')
# Out:
# Text(0, 0.5, 'verbosity coefficient')

# %%
sum(f1.dz.data)
# Out:
# 5500.0
